# %% [markdown]
# ## Feature Descriptors

# %% [markdown]
# There are many Feature Decribing Techniques for better feature Extraction from any image:
#
# 1) Histogram of Oriented Gradients
# 2) Scale Invarient Feature Transform
# 3) Speeded-up Robust feature

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# %%
image = imread(r"D:\PYTHON_Programmes\Python_Projects\2105800_ML_Projects\Image_Classification_Projects\catsAndDogs40\train\dog\5.jpg")
imshow(image)
image.shape
# Out:
# (160, 160, 3)

# %%
resize_img = resize(image, (128,64))
# imshow(resize_img)
resize_img.shape

fd, hog_image = hog(resize_img, orientations=9, pixels_per_cell=(8,8), cells_per_block=(2,2), visualize=True, channel_axis=2)
fd.shape

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0,10))

fig, (ax1, ax2)=plt.subplots(1, 2, figsize=(10,5))

ax1.imshow(resize_img)
ax1.axis("on")
ax1.set_title("Original Image")

ax2.imshow(hog_image_rescaled)
ax2.axis("on")
ax2.set_title("HOG feature-extracted image")
# Out:
# Text(0.5, 1.0, 'HOG feature-extracted image')

# %%
retina_img1 = imread(r"D:\PYTHON_Programmes\Python_Projects\2105800_ML_Projects\Image_Classification_Projects\DR_Dataset\images.jpeg", as_gray=False)
imshow(retina_img1)
retina_img1.shape
# Out:
# (183, 275, 3)

# %%
resize_retina_img1 = resize(retina_img1, (182,91))
imshow(resize_retina_img1)

# %%
fd, hog_retina_img1 = hog(resize_retina_img1, orientations=9, pixels_per_cell=(8,8), cells_per_block=(2,2), visualize=True, channel_axis=2)
hog_rimage1_rescaled = exposure.rescale_intensity(hog_retina_img1, in_range=(0,10))
imshow(hog_rimage1_rescaled)

# %% [markdown]
# Hence, we can clearly see that the exudates feature is not recognized much by using the hog image feature extractor. This image extraction technique is better to identify features variating by lines and are clearly evident. However, the presence of exudates is not clearly seen in the feature extracted HOG image. Also, the blood vessels are not clear which is why using this feature extraction technique may not be beneficial and may not yield accurate results.

# %% [markdown]
# This type of feature extraction may be useful for person identification and my allow in clearly identifying or classifying various images of various entities into seperate classes. However, identification of existance of particular features is very difficult.
